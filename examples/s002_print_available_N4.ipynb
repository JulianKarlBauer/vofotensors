# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

# %%
import vofotensors as vot

# %%
print("Available parameterizations of fourth order fiber orientation tensors:\n")
vot.utils.print_nested(vot.fabric_tensors.N4s_parametric)
# Out:
# Available parameterizations of fourth order fiber orientation tensors:
#
# ###
# Group: planar
# alpha1_d1_d8
# Matrix([
# [9*alpha1/14 + 59/105,   43/210 - 3*alpha1/28,   3*alpha1/14 + 2/15,                  0,           0,         -sqrt(2)*d7],
# [43/210 - 3*alpha1/28, 109/210 - 15*alpha1/28, 37/210 - 3*alpha1/28,                  0, -sqrt(2)*d7,          sqrt(2)*d9],
# [  3*alpha1/14 + 2/15,   37/210 - 3*alpha1/28, 19/210 - 3*alpha1/28,                  0,  sqrt(2)*d7, -sqrt(2)*(-d7 + d9)],
# [                   0,                      0,                    0, 3/35 - 3*alpha1/14, 2*d7 - 2*d9,               -2*d7],
# [                   0,            -sqrt(2)*d7,           sqrt(2)*d7,        2*d7 - 2*d9,  3*alpha1/7,                   0],
# [         -sqrt(2)*d7,             sqrt(2)*d9,  -sqrt(2)*(-d7 + d9),              -2*d7,           0,   1/7 - 3*alpha1/14]])
#
# la1_d1_d8
# Matrix([
# [ 6*la1/7 + 2/15,   29/105 - la1/7,     2*la1/7 - 1/105,              0,             0,         -sqrt(2)*d7],
# [ 29/105 - la1/7, 92/105 - 5*la1/7,      26/105 - la1/7,              0,   -sqrt(2)*d7,          sqrt(2)*d9],
# [2*la1/7 - 1/105,   26/105 - la1/7,      17/105 - la1/7,              0,    sqrt(2)*d7, -sqrt(2)*(-d7 + d9)],
# [              0,                0,                   0, 8/35 - 2*la1/7,   2*d7 - 2*d9,               -2*d7],
# [              0,      -sqrt(2)*d7,          sqrt(2)*d7,    2*d7 - 2*d9, 4*la1/7 - 2/7,                   0],
# [    -sqrt(2)*d7,       sqrt(2)*d9, -sqrt(2)*(-d7 + d9),          -2*d7,             0,       2/7 - 2*la1/7]])
#
# ###
# Group: transv_isotropic
# alpha1_rho1
# Matrix([
# [6*alpha1/7 + 8*rho1 + 1/3,   alpha1/14 - 4*rho1 + 1/5,   alpha1/14 - 4*rho1 + 1/5,                           0,                        0,                        0],
# [ alpha1/14 - 4*rho1 + 1/5, -3*alpha1/7 + 3*rho1 + 1/3,     -alpha1/7 + rho1 + 1/5,                           0,                        0,                        0],
# [ alpha1/14 - 4*rho1 + 1/5,     -alpha1/7 + rho1 + 1/5, -3*alpha1/7 + 3*rho1 + 1/3,                           0,                        0,                        0],
# [                        0,                          0,                          0, -2*alpha1/7 + 2*rho1 + 2/15,                        0,                        0],
# [                        0,                          0,                          0,                           0, alpha1/7 - 8*rho1 + 2/15,                        0],
# [                        0,                          0,                          0,                           0,                        0, alpha1/7 - 8*rho1 + 2/15]])
#
# alpha2_rho2
# Matrix([
# [-3*alpha2/7 + 3*rho2 + 1/3,  alpha2/14 - 4*rho2 + 1/5,     -alpha2/7 + rho2 + 1/5,                        0,                           0,                        0],
# [  alpha2/14 - 4*rho2 + 1/5, 6*alpha2/7 + 8*rho2 + 1/3,   alpha2/14 - 4*rho2 + 1/5,                        0,                           0,                        0],
# [    -alpha2/7 + rho2 + 1/5,  alpha2/14 - 4*rho2 + 1/5, -3*alpha2/7 + 3*rho2 + 1/3,                        0,                           0,                        0],
# [                         0,                         0,                          0, alpha2/7 - 8*rho2 + 2/15,                           0,                        0],
# [                         0,                         0,                          0,                        0, -2*alpha2/7 + 2*rho2 + 2/15,                        0],
# [                         0,                         0,                          0,                        0,                           0, alpha2/7 - 8*rho2 + 2/15]])
#
# alpha3_rho3
# Matrix([
# [-3*alpha3/7 + 3*rho3 + 1/3,     -alpha3/7 + rho3 + 1/5,  alpha3/14 - 4*rho3 + 1/5,                        0,                        0,                           0],
# [    -alpha3/7 + rho3 + 1/5, -3*alpha3/7 + 3*rho3 + 1/3,  alpha3/14 - 4*rho3 + 1/5,                        0,                        0,                           0],
# [  alpha3/14 - 4*rho3 + 1/5,   alpha3/14 - 4*rho3 + 1/5, 6*alpha3/7 + 8*rho3 + 1/3,                        0,                        0,                           0],
# [                         0,                          0,                         0, alpha3/7 - 8*rho3 + 2/15,                        0,                           0],
# [                         0,                          0,                         0,                        0, alpha3/7 - 8*rho3 + 2/15,                           0],
# [                         0,                          0,                         0,                        0,                        0, -2*alpha3/7 + 2*rho3 + 2/15]])
#
# ###
# Group: orthotropic
# la1_l2_d1_d2_d3
# Matrix([
# [  -d1 - d2 + 6*la1/7 + 1/21, d1 + la1/7 + la2/7 + 11/105,                  d2 - la2/7 + 26/105,                     0,                     0,                               0],
# [d1 + la1/7 + la2/7 + 11/105,   -d1 - d3 + 6*la2/7 + 1/21,                  d3 - la1/7 + 26/105,                     0,                     0,                               0],
# [        d2 - la2/7 + 26/105,         d3 - la1/7 + 26/105, -d2 - d3 - 6*la1/7 - 6*la2/7 + 19/21,                     0,                     0,                               0],
# [                          0,                           0,                                    0, 2*d3 - 2*la1/7 + 8/35,                     0,                               0],
# [                          0,                           0,                                    0,                     0, 2*d2 - 2*la2/7 + 8/35,                               0],
# [                          0,                           0,                                    0,                     0,                     0, 2*d1 + 2*la1/7 + 2*la2/7 - 2/35]])
#
# alpha1_alpha3_rho1_rho2_rho3
# Matrix([
# [6*alpha1/7 - 3*alpha3/7 + 8*rho1 + 3*rho2 + 3*rho3 + 1/3,       alpha1/14 - alpha3/7 - 4*rho1 - 4*rho2 + rho3 + 1/5,      alpha1/14 + alpha3/14 - 4*rho1 + rho2 - 4*rho3 + 1/5,                                                        0,                                                     0,                                                       0],
# [     alpha1/14 - alpha3/7 - 4*rho1 - 4*rho2 + rho3 + 1/5, -3*alpha1/7 - 3*alpha3/7 + 3*rho1 + 8*rho2 + 3*rho3 + 1/3,      -alpha1/7 + alpha3/14 + rho1 - 4*rho2 - 4*rho3 + 1/5,                                                        0,                                                     0,                                                       0],
# [    alpha1/14 + alpha3/14 - 4*rho1 + rho2 - 4*rho3 + 1/5,      -alpha1/7 + alpha3/14 + rho1 - 4*rho2 - 4*rho3 + 1/5, -3*alpha1/7 + 6*alpha3/7 + 3*rho1 + 3*rho2 + 8*rho3 + 1/3,                                                        0,                                                     0,                                                       0],
# [                                                       0,                                                         0,                                                         0, -2*alpha1/7 + alpha3/7 + 2*rho1 - 8*rho2 - 8*rho3 + 2/15,                                                     0,                                                       0],
# [                                                       0,                                                         0,                                                         0,                                                        0, alpha1/7 + alpha3/7 - 8*rho1 + 2*rho2 - 8*rho3 + 2/15,                                                       0],
# [                                                       0,                                                         0,                                                         0,                                                        0,                                                     0, alpha1/7 - 2*alpha3/7 - 8*rho1 - 8*rho2 + 2*rho3 + 2/15]])
#
# alpha1_alpha3_d1_d2_d3
# Matrix([
# [6*alpha1/7 - 3*alpha3/7 - d1 - d2 + 1/3,          alpha1/14 - alpha3/7 + d1 + 1/5,         alpha1/14 + alpha3/14 + d2 + 1/5,                                    0,                                 0,                                   0],
# [        alpha1/14 - alpha3/7 + d1 + 1/5, -3*alpha1/7 - 3*alpha3/7 - d1 - d3 + 1/3,         -alpha1/7 + alpha3/14 + d3 + 1/5,                                    0,                                 0,                                   0],
# [       alpha1/14 + alpha3/14 + d2 + 1/5,         -alpha1/7 + alpha3/14 + d3 + 1/5, -3*alpha1/7 + 6*alpha3/7 - d2 - d3 + 1/3,                                    0,                                 0,                                   0],
# [                                      0,                                        0,                                        0, -2*alpha1/7 + alpha3/7 + 2*d3 + 2/15,                                 0,                                   0],
# [                                      0,                                        0,                                        0,                                    0, alpha1/7 + alpha3/7 + 2*d2 + 2/15,                                   0],
# [                                      0,                                        0,                                        0,                                    0,                                 0, alpha1/7 - 2*alpha3/7 + 2*d1 + 2/15]])
#
# ###
# Group: monoclinic
# alpha1_alpha3_d1_d2_d3_d4_d5
# Matrix([
# [6*alpha1/7 - 3*alpha3/7 - d1 - d2 + 1/3,          alpha1/14 - alpha3/7 + d1 + 1/5,         alpha1/14 + alpha3/14 + d2 + 1/5,                             -d4 - d5,                                 0,                                   0],
# [        alpha1/14 - alpha3/7 + d1 + 1/5, -3*alpha1/7 - 3*alpha3/7 - d1 - d3 + 1/3,         -alpha1/7 + alpha3/14 + d3 + 1/5,                                   d4,                                 0,                                   0],
# [       alpha1/14 + alpha3/14 + d2 + 1/5,         -alpha1/7 + alpha3/14 + d3 + 1/5, -3*alpha1/7 + 6*alpha3/7 - d2 - d3 + 1/3,                                   d5,                                 0,                                   0],
# [                               -d4 - d5,                                       d4,                                       d5, -2*alpha1/7 + alpha3/7 + 2*d3 + 2/15,                                 0,                                   0],
# [                                      0,                                        0,                                        0,                                    0, alpha1/7 + alpha3/7 + 2*d2 + 2/15,                  -sqrt(2)*(d4 + d5)],
# [                                      0,                                        0,                                        0,                                    0,                -sqrt(2)*(d4 + d5), alpha1/7 - 2*alpha3/7 + 2*d1 + 2/15]])
#
# ###
# Group: triclinic
# la1_la2_d1_d2_d3_d4_d5_d6_d7_d8_d9
# Matrix([
# [  -d1 - d2 + 6*la1/7 + 1/21, d1 + la1/7 + la2/7 + 11/105,                  d2 - la2/7 + 26/105,    -sqrt(2)*(d4 + d5),            sqrt(2)*d6,                      sqrt(2)*d8],
# [d1 + la1/7 + la2/7 + 11/105,   -d1 - d3 + 6*la2/7 + 1/21,                  d3 - la1/7 + 26/105,            sqrt(2)*d4,    -sqrt(2)*(d6 + d7),                      sqrt(2)*d9],
# [        d2 - la2/7 + 26/105,         d3 - la1/7 + 26/105, -d2 - d3 - 6*la1/7 - 6*la2/7 + 19/21,            sqrt(2)*d5,            sqrt(2)*d7,              -sqrt(2)*(d8 + d9)],
# [         -sqrt(2)*(d4 + d5),                  sqrt(2)*d4,                           sqrt(2)*d5, 2*d3 - 2*la1/7 + 8/35,          -2*d8 - 2*d9,                    -2*d6 - 2*d7],
# [                 sqrt(2)*d6,          -sqrt(2)*(d6 + d7),                           sqrt(2)*d7,          -2*d8 - 2*d9, 2*d2 - 2*la2/7 + 8/35,                    -2*d4 - 2*d5],
# [                 sqrt(2)*d8,                  sqrt(2)*d9,                   -sqrt(2)*(d8 + d9),          -2*d6 - 2*d7,          -2*d4 - 2*d5, 2*d1 + 2*la1/7 + 2*la2/7 - 2/35]])
